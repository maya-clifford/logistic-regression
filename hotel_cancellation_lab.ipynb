# %% [markdown]
# # 🏨 Hotel Cancellation Prediction: Logistic Regression Lab
# ## Can we predict which bookings will be cancelled before they happen?
#
# ---
#
# ### The Business Problem
#
# Hotel cancellations are a massive headache for the hospitality industry.
# Consider a hotel with 200 rooms that is fully booked for a Saturday night:
#
# - If **20% of bookings cancel** (a realistic figure), the hotel loses revenue on 40 rooms it could have re-sold.
# - If the hotel **overbooks aggressively** and fewer people cancel than expected, it must walk guests to a competitor — destroying customer loyalty.
# - You are a data scientist at a fast growing hotel brand and they need a better way to predict cancellations, they have a pretty good size
# dataset and would like you to help. If the model works well you get a 10% bonus of all the recovered revenue!
#
# **A good cancellation-prediction model lets hotels:**
# 1. **Optimize overbooking** — sell the right number of extra rooms so the hotel fills up even after cancellations.
# 2.  **Improve staffing** — if 30% of tonight's bookings will cancel, fewer housekeepers and front-desk staff are needed.
# 3.  **Target at-risk bookings** — reach out proactively with incentives (free breakfast, discount upgrade) to guests who are likely to cancel.
#
# ### The Dataset
#
# We are working with the **Hotel Booking Demand** dataset (~119 k real bookings from two Portuguese hotels).
# Our **target variable** is `is_canceled`: `1` if the booking was cancelled, `0` if the guest actually showed up.
#
# ### What You Will Build
#
# | Model | Key idea |
# |-------|----------|
# | **Model 1** | Baseline pipeline — default solver (`lbfgs`), one-hot encoding + min-max scaling |
# | **Model 2** | Solver exploration — try using different solvers and see if the model improves |
# | **Model 3** | Class-weighted logistic regression + cross-validation to handle imbalanced labels |

# %% [markdown]
# ---
# ## 1 · Setup & Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    roc_auc_score, roc_curve,
    classification_report
)

sns.set_style('whitegrid')

# %%
df = pd.read_csv('hotels.csv')

# %% [markdown]
# ---
# ## 2 · Exploratory Data Analysis
#
# Before building any model we need to **understand our data**.

# %%
# Print out summary stats and basic info on the dataset, what trends do you notice?
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  str
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  str
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# One thing I notice is that a lot of the variables have 75th percentile values of 0, meaning that a vast majority of the inputs for those features are 0. Also, most of the columns have no null values. The scales for some of the variables are very different, showing that we will have to scale all of the columns to make the regression accurate.

# %%
# Calculate prevalence of the target value, how hard of problem is this going to be?
y = df['is_canceled']
prevalance = y.mean() * 100
print(f'The prevalance is {prevalance:.2f} %')
# Out:
# The prevalance is 37.04 %

# %% [markdown]
# The prevalance is 37%, meaning that this shouldn't be too hard of a problem. There are enough canceled reservations in the dataset that our model will have a good amount of data to base its predictions on.

# %% [markdown]
# ---
# ## 3 · Feature Engineering - Preparation
#
# Before building any model we need to **understand our data**.

# %%
# Check for missing data and drop features with too many missing values, there are some. 
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# drop country, agent, and company columns as they have many missing values 
# the only other column with any missing values is children, but that only has 4 missing so it should still be useful 
df = df.drop(['country', 'agent', 'company'], axis=1)

# %%
# fill the missing values in children with 0 
df['children'] = df['children'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  str
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  str
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# There are two other features that need to be dropped because they  directly leak the target variable.
# Another way to say this is they represent leakage in the dataset.
# ReservationStatus and  directly leaks the target variable since one of the categories for it is Canceled 
# reservation status date also leaks the target varaible because if the date is before the arrival date then they cancelled
df = df.drop(['reservation_status', 'reservation_status_date'], axis=1)

# %% [markdown]
# ---
# ### Feature groups, see step 4 in the example (i think it goes 1,2,4 I deleted 3 and didn't change the numbering)
#
# Create lists for the **numerical** and **categorical** so we can apply the right transformations to each group inside a `ColumnTransformer`.
#
# > **Why scale numerics?** Logistic regression uses gradient descent internally.
# > Features on very different scales (e.g. `lead_time` 0–737 vs `adults` 0–4) slow convergence.
# > `StandardScaler` fixes this by converting each feature to mean=0, std=1.
#
# > **Why one-hot encode categoricals?** Logistic regression can't handle strings.
# > One-hot encoding converts each category into its own binary (0/1) column.
#
# Keep in mind that we want to use the pipeline package to handle this preprocessing so create lists of names of numeric and category then pass them into the pipeline, not necessarily creating different dataframes.

# %%
# change ArrivalDateMonth to a numeric variable by replacing month name with the number month it is in the year
df['arrival_date_month'] = df['arrival_date_month'].replace({'January':1, 'February':2, 'March':3, 'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12})
# print(df['arrival_date_month'].unique())
df['arrival_date_month'] = df['arrival_date_month'].astype(int)

# %%
# Prepare for the pipeline make sure to do so for both **numerical** and **categorical**. 
# Generate dataframe for the features and target variable, X and y.

# make the list of numeric columns by getting a list of all int and float columns
numeric = list(df.select_dtypes(include=['int64', 'float64']).columns)
numeric.remove('is_canceled')
# look at the data dictionary to find the categorical data 
categorical = ['hotel', 'assigned_room_type', 'customer_type', 'deposit_type', 'distribution_channel', 'market_segment', 'meal', 'reserved_room_type']
df[categorical] = df[categorical].astype('category')

# make the pipline that uses MinMaxScaler on numeric data and OneHotEncoding on categorical data 
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical),
    ('num', MinMaxScaler(), numeric) # numerics passed through unchanged
])

# %%
X = df.drop(['is_canceled'], axis=1)
y = df['is_canceled']

# %%
# Train / test split — 80/20, stratified so class ratios are preserved 
train_X, test_X, train_y, test_y = train_test_split(X, y, train_size=0.8, random_state=42, stratify=y)

# %% [markdown]
# ---
# ## 4 · Model Building and Evaluation
#
# Now we are going to build our **model pipeline** and use the transformers

# %% [markdown]
# ---
# Model 1 — Baseline Logistic Regression
#
# Our first pipeline is intentionally **simple**.
# The goal is to establish a baseline score we can try to beat later.
# Transformer categorical using one-hot encoding and numerical using the MinMaxscaler()
#
# X_raw  →  ColumnTransformer  →  LogisticRegression(solver='lbfgs')
#            (scale + encode)
#
#
# **`lbfgs`** (Limited-memory Broyden–Fletcher–Goldfarb–Shanno) is sklearn's default solver, like we talked about in class

# %%
# make the pipeline that first uses the preprocessing pipeline we created before on train_X as the first step and then 
# run logistic regression on it
pipe_m1 = Pipeline(steps=[
    # the first step is the preprocessor made earlier (one hot encode categorical variables and use minmaxscaler on numeric)
    ('prep',  preprocessor),
    # make the model logistic regression with the lbfgs (default) solver
    # make the max iterations 5,000 so the regression stops running eventually and set the random state so we get the same model every time
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='lbfgs'))
])
# fit this pipeline to the train set 
pipe_m1.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %% [markdown]
# ---
#  Model 1 Evaluation: Now that the model is build lets evaluate the model using confusion matrix and ROC/AUC. Give the goal of your assignment how well does the model work?
#
# The Confusion Matrix Will Be Important Evaluation Tool
#
# For a hotel-cancellation problem the four cells of the confusion matrix have real business meaning:
#
# | | Predicted: Kept | Predicted: Cancelled |
# |---|---|---|
# | **Actual: Kept** |  **True Negative (TN)** — correctly identified loyal guest |  **False Positive (FP)** — wrongly flagged a loyal guest as a canceller |
# | **Actual: Cancelled** |  **False Negative (FN)** — missed a cancellation (costly!) |  **True Positive (TP)** — correctly predicted a cancellation |
#
# **Business impact:**
# - **False Negatives** are expensive — we didn't anticipate the cancellation, so we can't fill the room.
# - **False Positives** are annoying but cheaper — we might over-staff or over-book slightly.

# %%
# make the confusion matrix

# create a new data frame with the predictions for the test set 
y_pred_m1 = pipe_m1.predict(test_X)
# use the confusion_matrix function to make the confusion matrix of the predictions for the test set versus the actual values 
cm_m1 = confusion_matrix(test_y, y_pred_m1)
# make a variable that holds the display of the confusion matrix made above 
disp_m1 = ConfusionMatrixDisplay(confusion_matrix=cm_m1, display_labels=['Kept', 'Canceled'])
# plot the display of the confusion matrix
disp_m1.plot(cmap='Blues')
plt.title('Model 1 — Confusion Matrix')
plt.tight_layout()
plt.show()

# print the classification report of the actual and predicted values on the test set 
print(classification_report(test_y, y_pred_m1, target_names=['Kept', 'Canceled']))

# make an array of the probabilities of each data point being canceled 
y_proba_m1 = pipe_m1.predict_proba(test_X)[:, 1]
# pring the AUC score of the model 
print(f'AUC score: {roc_auc_score(test_y, y_proba_m1):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.79      0.93      0.86     15033
#     Canceled       0.83      0.59      0.69      8845
#
#     accuracy                           0.80     23878
#    macro avg       0.81      0.76      0.77     23878
# weighted avg       0.81      0.80      0.80     23878
#
# AUC score: 0.8555

# %% [markdown]
# This model has a good amount of false negatives which isn't good for our purposes. Out of the reservations that actually canceled on the test set,
# it predicted 5,246 accurately and produced false negatives for 3,599 of them. Although it did correctly predict more than half of the cancelations, we want the rate of false neatives to be less since they're so costly.

# %% [markdown]
# ---
# ## 5 · Model 2 — Exploring Different Solvers
#
# - Adjust your model object in the pipeline then evaluate again using confusion matrix and ROC/AUC. Make sure to eval on the test set. You should create a model_2_pipe, use much of the same code but create a new pipeline for each model
#
# Sklearn's `LogisticRegression` supports several **solvers** (optimisation algorithms) and
# **regularisation strategies** controlled by `l1_ratio` and `C`.
#
# | Solver | Best for |
# |--------|----------|
# | `lbfgs` | Default; works well on most datasets (L2 regularisation) |
# | `liblinear` | Smaller datasets; supports L1 via `l1_ratio=1` |
# | `saga` | Large datasets; supports L1, L2, and ElasticNet |
#
#
# Did the model improve based on the various solvers?

# %%
# make the second pipeline with the liblinear solver and L1
# following the same process as question 4 but specify the different solver and value for l1_ratio
pipe_m2 = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='liblinear', l1_ratio=1))
])

pipe_m2.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %%
# use the same code as question 4 to make the confusion matrix and the classification report for the new model 
y_pred_m2 = pipe_m2.predict(test_X)
cm_m2 = confusion_matrix(test_y, y_pred_m2)
disp_m2 = ConfusionMatrixDisplay(confusion_matrix=cm_m2, display_labels=['Kept', 'Canceled'])
disp_m2.plot(cmap='Blues')
plt.title('Model 2 — Confusion Matrix')
plt.tight_layout()
plt.show()

print(classification_report(test_y, y_pred_m2, target_names=['Kept', 'Canceled']))
y_proba_m2 = pipe_m2.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m2):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.80      0.93      0.86     15033
#     Canceled       0.84      0.61      0.71      8845
#
#     accuracy                           0.81     23878
#    macro avg       0.82      0.77      0.79     23878
# weighted avg       0.82      0.81      0.81     23878
#
# AUC score: 0.8616

# %% [markdown]
# This model with the liblinear solver is slightly better than the first one, with about 180 less false negatives, but it isn't signifigantly better overall.

# %%
# try the liblinear solver without L1, keeping the pipeline the same otherwise (the default value for 
# l1_ratio is 0, so we don't need to include that in the logistic regression )
pipe_m3 = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='liblinear'))
])

pipe_m3.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %%
y_pred_m3 = pipe_m3.predict(test_X)
cm_m3 = confusion_matrix(test_y, y_pred_m3)
disp_m3 = ConfusionMatrixDisplay(confusion_matrix=cm_m3, display_labels=['Kept', 'Canceled'])
disp_m3.plot(cmap='Blues')
plt.title('Model 3 — Confusion Matrix')
plt.tight_layout()
plt.show()

print(classification_report(test_y, y_pred_m3, target_names=['Kept', 'Canceled']))
y_proba_m3 = pipe_m3.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m3):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.80      0.93      0.86     15033
#     Canceled       0.83      0.59      0.69      8845
#
#     accuracy                           0.80     23878
#    macro avg       0.81      0.76      0.77     23878
# weighted avg       0.81      0.80      0.80     23878
#
# AUC score: 0.8555

# %% [markdown]
# The liblinear solver without L1 performs exactly the same as our default solver, so we don't want to use this model.

# %%
# now try to make a model using the saga solver with a l1_ratio of 1 
pipe_m4 = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='saga', l1_ratio=1))
])

pipe_m4.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %%
y_pred_m4 = pipe_m4.predict(test_X)
cm_m4 = confusion_matrix(test_y, y_pred_m4)
disp_m4 = ConfusionMatrixDisplay(confusion_matrix=cm_m4, display_labels=['Kept', 'Canceled'])
disp_m4.plot(cmap='Blues')
plt.title('Model 4 — Confusion Matrix')
plt.tight_layout()
plt.show()

print(classification_report(test_y, y_pred_m4, target_names=['Kept', 'Canceled']))
y_proba_m4 = pipe_m4.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m4):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.80      0.93      0.86     15033
#     Canceled       0.84      0.61      0.71      8845
#
#     accuracy                           0.81     23878
#    macro avg       0.82      0.77      0.78     23878
# weighted avg       0.82      0.81      0.80     23878
#
# AUC score: 0.8615

# %% [markdown]
# Using the saga solver with l1_ratio=1 performs slightly better than the default solver and liblinear without a specified l1 ratio, but it's a little bit worse than liblinear with a l1 ratio of 1.

# %%
# keep using the sage solver but have a l1_ratio of 0.5 to try ElasticNet 
pipe_m5 = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='saga', l1_ratio=0.5))
])

pipe_m5.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %%
y_pred_m5 = pipe_m5.predict(test_X)
cm_m5 = confusion_matrix(test_y, y_pred_m5)
disp_m5 = ConfusionMatrixDisplay(confusion_matrix=cm_m5, display_labels=['Kept', 'Canceled'])
disp_m5.plot(cmap='Blues')
plt.title('Model 5 — Confusion Matrix')
plt.tight_layout()
plt.show()

print(classification_report(test_y, y_pred_m5, target_names=['Kept', 'Canceled']))
y_proba_m5 = pipe_m5.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m5):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.80      0.93      0.86     15033
#     Canceled       0.83      0.60      0.70      8845
#
#     accuracy                           0.81     23878
#    macro avg       0.82      0.77      0.78     23878
# weighted avg       0.81      0.81      0.80     23878
#
# AUC score: 0.8581

# %%
# use the saga solver without a specifid l1_ratio (meaning its value is 0) so L2 can be used 
pipe_m6 = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='saga'))
])

pipe_m6.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %%
y_pred_m6 = pipe_m6.predict(test_X)
cm_m6 = confusion_matrix(test_y, y_pred_m6)
disp_m6 = ConfusionMatrixDisplay(confusion_matrix=cm_m6, display_labels=['Kept', 'Canceled'])
disp_m6.plot(cmap='Blues')
plt.title('Model 6 — Confusion Matrix')
plt.tight_layout()
plt.show()

print(classification_report(test_y, y_pred_m6, target_names=['Kept', 'Canceled']))
y_proba_m6 = pipe_m6.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m6):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.79      0.93      0.86     15033
#     Canceled       0.83      0.59      0.69      8845
#
#     accuracy                           0.80     23878
#    macro avg       0.81      0.76      0.77     23878
# weighted avg       0.81      0.80      0.80     23878
#
# AUC score: 0.8555

# %%
# since our best model so far was the liblinear solver with a L1 ratio of 1, try changing the C values on it, starting with C=0.5
pipe_m7 = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='liblinear', l1_ratio=1, C=0.5))
])

pipe_m7.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %%
y_pred_m7 = pipe_m7.predict(test_X)
cm_m7 = confusion_matrix(test_y, y_pred_m7)
disp_m7 = ConfusionMatrixDisplay(confusion_matrix=cm_m7, display_labels=['Kept', 'Canceled'])
disp_m7.plot(cmap='Blues')
plt.title('Model 7 — Confusion Matrix')
plt.tight_layout()
plt.show()

print(classification_report(test_y, y_pred_m7, target_names=['Kept', 'Canceled']))
y_proba_m7 = pipe_m7.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m7):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.80      0.93      0.86     15033
#     Canceled       0.84      0.61      0.71      8845
#
#     accuracy                           0.81     23878
#    macro avg       0.82      0.77      0.79     23878
# weighted avg       0.82      0.81      0.81     23878
#
# AUC score: 0.8614

# %%
# now try it with a C of 2 
pipe_m8 = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='liblinear', l1_ratio=1, C=2))
])

pipe_m8.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %%
y_pred_m8 = pipe_m8.predict(test_X)
cm_m8 = confusion_matrix(test_y, y_pred_m8)
disp_m8 = ConfusionMatrixDisplay(confusion_matrix=cm_m8, display_labels=['Kept', 'Canceled'])
disp_m8.plot(cmap='Blues')
plt.title('Model 8 — Confusion Matrix')
plt.tight_layout()
plt.show()

print(classification_report(test_y, y_pred_m8, target_names=['Kept', 'Canceled']))
y_proba_m8 = pipe_m8.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m8):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.80      0.93      0.86     15033
#     Canceled       0.84      0.61      0.71      8845
#
#     accuracy                           0.81     23878
#    macro avg       0.82      0.77      0.78     23878
# weighted avg       0.82      0.81      0.80     23878
#
# AUC score: 0.8616

# %%
# since the model with C=2 was better than C=1 and C=0.5, try it with an increased C of 5 
pipe_m9 = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='liblinear', l1_ratio=1, C=5))
])

pipe_m9.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %%
y_pred_m9 = pipe_m9.predict(test_X)
cm_m9 = confusion_matrix(test_y, y_pred_m9)
disp_m9 = ConfusionMatrixDisplay(confusion_matrix=cm_m9, display_labels=['Kept', 'Canceled'])
disp_m9.plot(cmap='Blues')
plt.title('Model 9 — Confusion Matrix')
plt.tight_layout()
plt.show()

print(classification_report(test_y, y_pred_m9, target_names=['Kept', 'Canceled']))
y_proba_m9 = pipe_m9.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m9):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.80      0.93      0.86     15033
#     Canceled       0.84      0.61      0.71      8845
#
#     accuracy                           0.81     23878
#    macro avg       0.82      0.77      0.78     23878
# weighted avg       0.82      0.81      0.80     23878
#
# AUC score: 0.8618

# %%
# since C=5 was also better, try with C=10
pipe_m10 = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='liblinear', l1_ratio=1, C=10))
])

pipe_m10.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %%
y_pred_m10 = pipe_m10.predict(test_X)
cm_m10 = confusion_matrix(test_y, y_pred_m10)
disp_m10 = ConfusionMatrixDisplay(confusion_matrix=cm_m10, display_labels=['Kept', 'Canceled'])
disp_m10.plot(cmap='Blues')
plt.title('Model 10 — Confusion Matrix')
plt.tight_layout()
plt.show()

print(classification_report(test_y, y_pred_m10, target_names=['Kept', 'Canceled']))
y_proba_m10 = pipe_m10.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m10):.4f}')
# Out:
#               precision    recall  f1-score   support
#
#         Kept       0.80      0.93      0.86     15033
#     Canceled       0.83      0.61      0.71      8845
#
#     accuracy                           0.81     23878
#    macro avg       0.82      0.77      0.78     23878
# weighted avg       0.82      0.81      0.80     23878
#
# AUC score: 0.8618

# %% [markdown]
# When the model has a C of 10 it gets worse, so our best model thus far is the liblinear solver with a l1_ratio of 1 and C=5.

# %%
# use our best model to create the model 2 pipeline
model_2_pipe = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, n_jobs=-1, solver='liblinear', l1_ratio=1, C=5))
])

model_2_pipe.fit(train_X, train_y)
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
# ...

# %% [markdown]
# ---
# ## 6 · Model 3 — Balanced Class Weights + Cross-Validation
#
# Build a final model (pipe_3) with a balanced class weight and use cross validation. As a reminder cv happens on the fit process not as part of the pipeline and we need to build our CV object, similar to the model object. .
#
# Use the example shown in class to see how to apply cross validation, balanced weight is a argument in the logreg function that you just need to apply as seen below.
#
# ### The Class Imbalance Problem
#
# Our dataset has ~63% non-cancellations and ~37% cancellations.
# A lazy model could achieve 63% accuracy by *always* predicting "Kept"!
# We saw that Models 1 and 2 sometimes struggled with **recall on the cancelled class**.
#
# ### Solution: `class_weight='balanced'`
#
# Setting `class_weight='balanced'` tells sklearn to automatically weight the training samples
# so that the minority class (cancellations) gets more attention during training.
#
# Specifically, each class gets weight = `n_samples / (n_classes × n_samples_in_class)`.
#
# ### Solution: Cross-Validation
#
# Instead of a single train/test split (which can be lucky or unlucky),
# **k-fold cross-validation** trains and evaluates the model on `k` different splits
# and reports the average — giving a much more reliable estimate of real-world performance.
#
# ```
# Fold 1: [train | train | train | train | VAL ]
# Fold 2: [train | train | train | VAL  | train]
# Fold 3: [train | train | VAL  | train | train]
# ...and so on
# ```
#
# ---
#
# ### Experiments
#
# - Change the number of folds from `5` to `10` — does the mean AUC change much?
# - Try removing `class_weight='balanced'` — what happens to recall on the cancelled class?

# %%
# make model_3_pipe as the best model from question 5 but with balanced class weights 
model_3_pipe = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, solver='liblinear', l1_ratio=1, C=5, class_weight='balanced'))
])

model_3_pipe.fit(train_X, train_y)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
#                                                    'reserved_room_type']),
#                                                  ('num', MinMaxScaler(),
#                                                   ['lead_time',
#                                                    'arrival_date_year',
# ...

# %%
# print the auc score 
y_proba_m = model_3_pipe.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m):.4f}')
# Out:
# AUC score: 0.8618

# %%
cv_scores = cross_val_score(model_3_pipe, train_X, train_y, cv=10, scoring='accuracy')

print(f"Cross-Validation Scores (Train): {cv_scores}")
print(f"Mean CV Accuracy: {cv_scores.mean():.4f}")
print(f"CV Standard Deviation: {cv_scores.std():.4f}")
# Out:
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# /workspaces/logistic-regression/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %% [markdown]
# Try with 5 folds instead of 10

# %%
cv_scores = cross_val_score(model_3_pipe, train_X, train_y, cv=5, scoring='accuracy')

print(f"Cross-Validation Scores (Train): {cv_scores}")
print(f"Mean CV Accuracy: {cv_scores.mean():.4f}")
print(f"CV Standard Deviation: {cv_scores.std():.4f}")
# Out:
# Cross-Validation Scores (Train): [0.78919541 0.78799141 0.78719506 0.78363522 0.78860852]
# Mean CV Accuracy: 0.7873
# CV Standard Deviation: 0.0020

# %% [markdown]
# When the folds of cross-validation switch from 10 to 5, there isn't a major difference in the mean cross validation scores (0.7872 vs. 0.7873). There is a slightly larger difference in the standard deviations, showing that the cross validation scores vary more when there are more folds, however, the mean score has little change when the folds are different.

# %% [markdown]
# Try without class_weights=balanced

# %%
model_3_pipe = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, solver='liblinear', l1_ratio=1, C=5))
])

model_3_pipe.fit(train_X, train_y)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['hotel',
#                                                    'assigned_room_type',
#                                                    'customer_type',
#                                                    'deposit_type',
#                                                    'distribution_channel',
#                                                    'market_segment', 'meal',
#                                                    'reserved_room_type']),
#                                                  ('num', MinMaxScaler(),
#                                                   ['lead_time',
#                                                    'arrival_date_year',
# ...

# %%
# print the auc score 
y_proba_m = model_3_pipe.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m):.4f}')
# Out:
# AUC score: 0.8618

# %%
cv_scores = cross_val_score(model_3_pipe, train_X, train_y, cv=10, scoring='accuracy')

print(f"Cross-Validation Scores (Train): {cv_scores}")
print(f"Mean CV Accuracy: {cv_scores.mean():.4f}")
print(f"CV Standard Deviation: {cv_scores.std():.4f}")
# Out:
# Cross-Validation Scores (Train): [0.81679229 0.81323283 0.81384148 0.8155167  0.80986284 0.8157261
#  0.80975814 0.80766412 0.80954874 0.80933934]
# Mean CV Accuracy: 0.8121
# CV Standard Deviation: 0.0031

# %% [markdown]
# When the class weights aren't balanced, the cross validation scores are actually slightly better.

# %% [markdown]
# ---
# ## 07 · Summary & Reflection
#
# ### What We Learned
#
# **Model Performance**
# - Which model worked best and why do you think that is the case? Write a short recommendation to your boss on how to proceed (1 paragraph)
#
# ### Challenge Extensions - extra 5 points for each
#
# If you want to push further:
#
# 1. **Tune `C`** using `GridSearchCV` over the range `[0.001, 0.01, 0.1, 1, 10, 100]`.
# 2. **Engineer new features** — e.g. `total_nights = stays_in_weekend_nights + stays_in_week_nights`.
# 3. **Try a different model** — replace `LogisticRegression` in the pipeline with `RandomForestClassifier` or `GradientBoostingClassifier`. Does AUC improve? or maybe kNN
# 4. **Interpret coefficients** — given that the variables have been standardized create a horizontal bar chart showing
# the rankings of the coeficients
#
# ---

# %% [markdown]
# The model that worked best was

# %% [markdown]
# Tune C using GridSearchCV:

# %% [markdown]
# Engineer New Features:

# %%
# make a total_nights column in df - use lambda function 
df['total_nights'] = df.apply(lambda row: row['stays_in_week_nights'] + row['stays_in_weekend_nights'], axis=1)

# %%
# add a total_price column by multiplying the adr (adjusted daily rate) column by the total_nights column 
df['total_price'] = df.apply(lambda row: row['adr']*row['total_nights'], axis=1)

# %%
# split into X and y and then train and test sets 
X = df.drop('is_canceled', axis=1)
y = df['is_canceled']

train_X, test_X, train_y, test_y = train_test_split(X, y, train_size=0.8, random_state=42, stratify=y)

# %%
# make the pipeline of our best model 
model_3_pipe = Pipeline(steps=[
    ('prep', preprocessor), 
    ('model', LogisticRegression(max_iter=5000, random_state=42, solver='liblinear', l1_ratio=1, C=5, class_weight='balanced'))
])

model_3_pipe.fit(train_X, train_y)

# %%
# print the auc score 
y_proba_m = model_3_pipe.predict_proba(test_X)[:, 1]
print(f'AUC score: {roc_auc_score(test_y, y_proba_m):.4f}')

# %% [markdown]
# Try a different model:

# %% [markdown]
# Interpret coefficients
